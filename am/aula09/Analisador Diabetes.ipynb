# %%
import pandas as pd

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
from sklearn.linear_model import LogisticRegression

# %%
diabetes_df = pd.read_csv("../../../dados/diabetes.csv")

# %%
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
plt.scatter(diabetes_df["Glucose"], diabetes_df["SkinThickness"], c=diabetes_df["Outcome"])
plt.show()

# %%
x = diabetes_df[["Glucose", "SkinThickness"]]

# %%
x_train = x.iloc[0:500]
x_test = x.iloc[500:]

# %%
y = diabetes_df["Outcome"]

# %%
y_train = y.iloc[0:500]
y_test = y.iloc[500:]

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.7873134328358209

# %%
model.predict([[140.0, 30.0]])
# Out:
# C:\Users\Professor\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
