# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in d:\usr\anaconda312\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in d:\usr\anaconda312\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in d:\usr\anaconda312\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\usr\anaconda312\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\usr\anaconda312\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\usr\anaconda312\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\usr\anaconda312\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\usr\anaconda312\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\usr\anaconda312\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\usr\anaconda312\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\usr\anaconda312\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl (301 kB)
#    ---------------------------------------- 0.0/301.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/301.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.4 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/301.4 kB 245.8 kB/s eta 0:00:02
#    ------------------------------- -------- 235.5/301.4 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 301.4/301.4 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
from matplotlib import pyplot as plt

# %%
from wordcloud import WordCloud

# %% [markdown]
# ## Este notebook é para tratamento de textos usando Stop Words

# %%
corpus = """rato roeu a roupa do rei de Roma,
O rato roeu a roupa do rei da Rússia,
O rato roeu a roupa do RodovaIho...
O rato a roer roía
E a rosa Rita Ramalho do rato a roer se ria.
O rato roeu a roupa do rei de roma
a rainha com raiva roeu o resto."""

# %% [markdown]
# ### Pre processamento do texto removendo caracteres de pontuação e espaços adicionais

# %%
corpus_lower = corpus.lower()

# %%
trans_table = str.maketrans('.,\n', '   ')
corpus_limpo = corpus_lower.translate(trans_table)

# %% [markdown]
# ### Criando as tokens a partir do Texto

# %%
tokens = corpus_limpo.split(" ")

# %% [markdown]
# ### Removendo os stop words

# %%
stop_words = ['a', 'o', 'da', 'do', 'e', 'que', 'com', 'se', 'de']

# %%
tokens_limpos = []
for token in tokens:
    if token != '' and token not in stop_words:
        tokens_limpos.append( token )
print("Tokens: ", tokens_limpos)
# Out:
# Tokens:  ['rato', 'roeu', 'roupa', 'rei', 'roma', 'rato', 'roeu', 'roupa', 'rei', 'rússia', 'rato', 'roeu', 'roupa', 'rodovaiho', 'rato', 'roer', 'roía', 'rosa', 'rita', 'ramalho', 'rato', 'roer', 'ria', 'rato', 'roeu', 'roupa', 'rei', 'roma', 'rainha', 'raiva', 'roeu', 'resto']

# %% [markdown]
# ### Criando o Bag Of Words com contagem de palavras

# %%
vocabulario = list(set(tokens_limpos))
print("Vocabulario: ", vocabulario)
# Out:
# Vocabulario:  ['roía', 'roupa', 'raiva', 'roeu', 'rainha', 'rosa', 'rei', 'roer', 'rússia', 'resto', 'roma', 'ramalho', 'rodovaiho', 'rita', 'rato', 'ria']

# %%
bag_of_words = {}
for token in tokens_limpos:
    if token in bag_of_words:
        bag_of_words[token] = bag_of_words[token] + 1
    else:
        bag_of_words[token] = 1
print("Bag of Words (com contagem): ", bag_of_words)
# Out:
# Bag of Words (com contagem):  {'rato': 6, 'roeu': 5, 'roupa': 4, 'rei': 3, 'roma': 2, 'rússia': 1, 'rodovaiho': 1, 'roer': 2, 'roía': 1, 'rosa': 1, 'rita': 1, 'ramalho': 1, 'ria': 1, 'rainha': 1, 'raiva': 1, 'resto': 1}

# %%
plt.barh(['SP', 'RJ', 'MG'], [50, 20, 10])
plt.show()

# %%
lista_palavras = []
lista_ocorrencias = []
for item in bag_of_words.items():
    lista_palavras.append( item[0] )
    lista_ocorrencias.append( item[1] )

# %%
plt.barh(lista_palavras, lista_ocorrencias)
plt.show()

# %%
cloud_generator = WordCloud(width=600, height=400, max_font_size=48, collocations=False)

# %%
texto_limpo = " ".join(tokens_limpos)

# %%
imagem1 = cloud_generator.generate( texto_limpo )

# %%
plt.figure(figsize=(10, 5))
plt.imshow(imagem1, interpolation="bilinear")
plt.axis("off")
plt.show()
